# %% [markdown]
# ## Installing Necessary Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U trl transformers accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.0/110.0 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 60.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.2 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 77.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.8/218.8 kB 25.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.4 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %% [markdown]
# # Dataset details
# Instacart Data can be downloaded from [here](https://www.kaggle.com/competitions/instacart-market-basket-analysis/data). We just need product & department csv files

# %%
import pandas as pd
df_product = pd.read_csv("/content/drive/MyDrive/products.csv")
df_dept = pd.read_csv('/content/drive/MyDrive/departments.csv')

# %%
df_joined = pd.merge(df_product, df_dept, on = ['department_id'])
df_joined['text'] = df_joined.apply(lambda row: row['product_name'] + " ->: " + row['department'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df_joined, test_size=0.2, random_state=42)

# %%
train_df.head(10)
# Out:
#        product_id                                       product_name  \
# 7361        10376                              Organic Caraway Seeds
# 32534       40131                         Original Laundry Detergent
# 1457        11913                                 Shelled Pistachios
# 5201        41392                   Harvest Berry Chewy Granola Bars
# 38539       28627              Veganic Sprouted Red Fife Raisin Bran
# 18377       29407                               Root Vegetable Cakes
# 28627       29571                                  Alta Dena 1% Milk
# 30283        3589                             Laundry Detergent Pods
# 32030       31685  Daily Shower Cleaner Scrub Free Refill, Fresh ...
# 28655       30119            Organic French Style Meyer Lemon Yogurt
#
#        aisle_id  department_id  department  \
# 7361        104             13      pantry
# 32534        75             17   household
# 1457        117             19      snacks
# 5201          3             19      snacks
# 38539       121             14   breakfast
# 18377        42              1      frozen
# 28627        84             16  dairy eggs
# 30283        75             17   household
# 32030       114             17   household
# 28655       120             16  dairy eggs
#
#                                                     text
# 7361                    Organic Caraway Seeds ->: pantry
# 32534           Original Laundry Detergent ->: household
# 1457                       Shelled Pistachios ->: snacks
# 5201         Harvest Berry Chewy Granola Bars ->: snacks
# 38539  Veganic Sprouted Red Fife Raisin Bran ->: brea...
# 18377                    Root Vegetable Cakes ->: frozen
# 28627                   Alta Dena 1% Milk ->: dairy eggs
# 30283               Laundry Detergent Pods ->: household
# 32030  Daily Shower Cleaner Scrub Free Refill, Fresh ...
# 28655  Organic French Style Meyer Lemon Yogurt ->: da...

# %%
test_df.head(10)
# Out:
#        product_id                                       product_name  \
# 33626       24154             Free & Clear Stage 4 Overnight Diapers
# 18192       27348  Beef pot roast with roasted potatoes, carrots,...
# 47099       27181                                      Coffee Liquer
# 48183       20577                                        Bread Rolls
# 22197       16472           French Milled Oval Almond Gourmande Soap
# 31573       24121                                           Dust Pan
# 45362        5477                            Roasted Pine Nut Hommus
# 14131       27921                 Cranberry Raspberry Juice Cocktail
# 26903        4786                          Sweet Cream Butter Salted
# 39417        8796                    Traditional Chicken Barley Soup
#
#        aisle_id  department_id     department  \
# 33626        56             18         babies
# 18192        38              1         frozen
# 47099       124              5        alcohol
# 48183        43              3         bakery
# 22197        25             11  personal care
# 31573       114             17      household
# 45362        67             20           deli
# 14131        98              7      beverages
# 26903        36             16     dairy eggs
# 39417        69             15   canned goods
#
#                                                     text
# 33626  Free & Clear Stage 4 Overnight Diapers ->: babies
# 18192  Beef pot roast with roasted potatoes, carrots,...
# 47099                          Coffee Liquer ->: alcohol
# 48183                             Bread Rolls ->: bakery
# 22197  French Milled Oval Almond Gourmande Soap ->: p...
# 31573                             Dust Pan ->: household
# 45362                   Roasted Pine Nut Hommus ->: deli
# 14131   Cranberry Raspberry Juice Cocktail ->: beverages
# 26903           Sweet Cream Butter Salted ->: dairy eggs
# 39417   Traditional Chicken Barley Soup ->: canned goods

# %%
from datasets import Dataset,DatasetDict
train_dataset_dict = DatasetDict({
    "train": Dataset.from_pandas(train_df),
})

# %% [markdown]
# ## Loading the model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer

model_name = "TinyPixel/Llama-2-7B-bf16-sharded"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/626 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00014.bin:   0%|          | 0.00/981M [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00005-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# Downloading (…)l-00006-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00007-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00008-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00009-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00010-of-00014.bin:   0%|          | 0.00/944M [00:00<?, ?B/s]
# Downloading (…)l-00011-of-00014.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)l-00012-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00013-of-00014.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# Downloading (…)l-00014-of-00014.bin:   0%|          | 0.00/847M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# Let's also load the tokenizer below

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/676 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %% [markdown]
# **Let's check what the base model predicts before finetuning. :)**

# %%
import transformers
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)


sequences = pipeline(
   ["“Free & Clear Stage 4 Overnight Diapers” ->:","Bread Rolls ->:","French Milled Oval Almond Gourmande Soap ->:"],
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq[0]['generated_text']}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1411: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Result: “Free & Clear Stage 4 Overnight Diapers” ->: 2019-06-10 13:49:57
#  фев 15, 2018... 520. 521. 522. 523. 524. 525. 526. 527. 528. 529.... 3210. 3211. 3212. 3213. 3214. 3215. 3216. 3217. 3218. 3219. 3220. 3221..... 520. 521. 522. 523. 524. 525
# Result: Bread Rolls ->: 2. Unterscheidung zwischen Back- und Brotlaube.
# * 1796: Johann Georg Krämer: Kleines Lehrbuch der Bäckerkunst. ->: Der Brotlauf.
# * 1804: Johann Georg Krämer: Vollständiges Lehr- und Handbuch der Bäckerkunst. ->: Der Brotlauf.
# * 1851: Julius Kollath: Handwerks-Lexikon. Brotbäcker, Brotweber.
# * 1929: Wilhelm Fuchs: Die Bäcker- und Bäckereiwirtschaft im Deutschen Reich. Brotlaube.
# * 1937: Wilhelm Fuchs: Handbuch für Bäcker. Brotlaube.
# * 1972: Heinz Döhnert: Die Brotlaube. Einführung in die
# Result: French Milled Oval Almond Gourmande Soap ->: https://www. nobody is perfect.
# It is the best and fastest way to get rid of those dark circles under our eyes. This is a good one. I am a huge fan of this soap.
# The first soap was made in France around the time of the French Revolution. 99 ($19) 100g ($34. This is a good one.
# Soap Opera Digest - Soaps. 7 out of 5 stars 62. The first soap was made in France around the time of the French Revolution.
# Soaps in Paris, France: Find TripAdvisor traveler reviews of Paris Soaps and search by price, location, and more. Soaps in Paris, France: Find TripAdvisor traveler reviews of Paris Soaps and search by price, location, and more.
# Feb 8, 201

# %% [markdown]
# Below we will load the configuration file in order to create the LoRA model. According to QLoRA paper, it is important to consider all linear layers in the transformer block for maximum performance.

# %%
from peft import LoraConfig

lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj","v_proj"]
)

# %% [markdown]
# ## Loading the trainer

# %% [markdown]
# Here we will use the [`SFTTrainer` from TRL library](https://huggingface.co/docs/trl/main/en/sft_trainer) that gives a wrapper around transformers `Trainer` to easily fine-tune models on instruction based datasets using PEFT adapters. Let's first load the training arguments below.

# %%
from transformers import TrainingArguments

output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 10
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 120
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %% [markdown]
# Then finally pass everthing to the trainer

# %%
from trl import SFTTrainer

max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_dict['train'],
    # train_dataset=data['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    # dataset_text_field="prediction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:122: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/39750 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:207: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %% [markdown]
# We will also pre-process the model by upcasting the layer norms in float 32 for more stable training

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Now let's train the model! Simply call `trainer.train()`

# %%
trainer.train()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.9
# Run data is saved locally in <code>/content/wandb/run-20230830_061726-vu54nwj6</code>
# Syncing run <strong><a href='https://wandb.ai/targetqna/huggingface/runs/vu54nwj6' target="_blank">fine-gorge-1</a></strong> to <a href='https://wandb.ai/targetqna/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/targetqna/huggingface' target="_blank">https://wandb.ai/targetqna/huggingface</a>
#  View run at <a href='https://wandb.ai/targetqna/huggingface/runs/vu54nwj6' target="_blank">https://wandb.ai/targetqna/huggingface/runs/vu54nwj6</a>
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 07:08, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.029100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.089600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.359200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.271200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.250100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.057500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.467000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.854300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.339800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>5.121500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>4.006300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.891700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>5.593400</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>3.793300</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.602300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.421600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>4.095400</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.177400</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>3.037700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.931900</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.480800</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>3.417400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.503500</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>2.328000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.431600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>3.597300</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.536500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.262900</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.441900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.343800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.694400</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.158100</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>2.403800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>3.648500</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>2.219200</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>2.346700</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>2.174500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.280600</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>2.297400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.020700</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.180200</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.026700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.079300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.908200</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>2.017200</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>3.048200</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>2.187500</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>3.778300</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.346400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.891700</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>2.064100</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>4.114900</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.598700</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>3.144300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.837900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.493200</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>2.032500</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.044000</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.145000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.034300</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>2.080700</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.485400</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>2.105200</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.703100</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>2.001200</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>2.096200</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.976400</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>2.030300</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.949100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.148000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>2.381200</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.801300</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.714300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.913700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2.108400</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>2.086400</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>2.073500</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>2.206400</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>2.132800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.063400</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.956200</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.853800</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.940500</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>2.037500</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>2.070600</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>2.025700</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.972000</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.829900</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.872900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.925700</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.904300</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.853000</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.866400</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>2.155600</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.864700</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.982200</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>2.240100</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.954700</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>2.064400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.016800</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>2.624100</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>2.481200</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2.419400</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>2.455800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>1.959900</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>2.329800</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>2.070800</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>2.043100</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>2.078700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.936300</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>2.023300</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.916000</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.781100</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>2.174900</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>2.115100</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.601000</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1.716500</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.813100</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.932400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.855200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=2.489347438017527, metrics={'train_runtime': 686.9412, 'train_samples_per_second': 2.795, 'train_steps_per_second': 0.175, 'total_flos': 627303342243840.0, 'train_loss': 2.489347438017527, 'epoch': 0.05})

# %%
lst_test_data = list(test_df['text'])

# %%
len(lst_test_data)
# Out:
# 9938

# %%
sample_size = 25
lst_test_data_short = lst_test_data[:sample_size]

# %%
import transformers

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

sequences = pipeline(
    lst_test_data_short,
    max_length=100,  #200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)

for ix,seq in enumerate(sequences):
    print(ix,seq[0]['generated_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# 0 Free & Clear Stage 4 Overnight Diapers ->: babies ->: diapers & wipes ->: disposable diapers ->: diapers ->: overnight diapers ->: overnight diapers ->: personal care products ->: babies personal care products personal care products ->: diapers & wipes personal care products personal care products personal care products personal care products ->: overnight diapers personal care products personal care products personal care products personal care products ->:
# 1 Beef pot roast with roasted potatoes, carrots, sweet onions, green beans, and a rich gravy Beef Pot Roast ->: frozen foods meat seafood & poultry ->: meats beef ->: beef products ->: frozen foods meat seafood & poultry meat seafood & poultry beef ->: beef products pork & beef products beef products beef pot ro
# 2 Coffee Liquer ->: alcohol beverages liquor ->: adult beverages ->: liquor ->: coffee liqueur original ->: non-alcoholic beverages personal care household goods personal care household goods personal care household goods personal care household goods ->: snacks snacks personal care household goods personal care household goods personal care household goods personal care household goods ->: snacks snacks ->: snacks ->: snack crackers ->: cheese
# 3 Bread Rolls ->: bakery & dairy eggs & dairy eggs & dairy eggs & dairy eggs & dairy eggs ->: bakery items pastries bread rolls ->: bakery items pastries bread rolls pastries ->: bakery items pastries bread rolls pastries pastries ->: bakery items pastries bread rolls pastries pastries pastries ->: bakery ->: pastries bread rolls ->: b
# 4 French Milled Oval Almond Gourmande Soap ->: personal care personal wash personal hygiene ->: personal care personal wash personal hygiene personal soap almonds ->: personal care personal wash personal hygiene babies r us ->: personal care personal wash personal hygiene personal soap ->: house household pets household items ->: personal care personal wash personal hygiene personal soap ->: personal care personal wash personal hygiene
# 5 Dust Pan ->: household essentials kitchen utensils baking & kitchen tools baking tools & gadgets dust pans & brooms ->: household essentials kitchen utensils baking & kitchen tools brooms & dust pans ->: household essentials baking & kitchen tools brooms & dust pans dust pans ->: home goods household items brooms & dust pans household cleaning ->: household essentials brooms & dust pans ->: personal care personal
# 6 Roasted Pine Nut Hommus ->: deli cheese eggs ->: dairy eggs ->: dairy eggs eggs ->: eggs eggs ->: eggs breakfast dairy ->: dairy breakfast dairy eggs ->: dairy eggs ->: dairy dairy eggs ->: dairy ->: international cuisine & ethnic foods ->: international cuisine international cuisine & ethnic foods ->: international cuisine ->: international cuisine & eth
# 7 Cranberry Raspberry Juice Cocktail ->: beverages other drinks juices cranberry raspberry juice cocktail ->: beverages alcoholic beverages beer, wine, spirits & liquors ->: non-alcoholic drinks beverages ->: beverages other drinks juices ->: snacks & pantry ->: pantry snack & baking items ->: pantry snack & b
# 8 Sweet Cream Butter Salted ->: dairy eggs dairy eggs eggs dairy eggs dairy eggs butter dairy eggs eggs dairy eggs dairy eggs ->: dairy eggs eggs dairy eggs eggs dairy eggs eggs ->: dairy eggs eggs dairy eggs eggs dairy eggs eggs dairy eggs ->: dairy eggs eggs dairy eggs eggs dairy eggs dairy eggs ->: dairy eggs eggs dairy eggs eggs dairy eggs dairy eggs ->:
# 9 Traditional Chicken Barley Soup ->: canned goods canned goods: soup ->: beverages: soups & broths ->: beverages: soups & broths: soups ->: beverages: soups & broths: soups ->: personal care personal care: personal care: personal care ->: personal care: personal care: personal care ->: personal care: personal care ->: personal care: personal care ->: personal care
# 10 Vanilla Unsweetened Cashewmilk ->: dairy eggs dairy eggs other dairy beverages almond dairy milk almond dairy milk almond cashew ->: other dairy beverages almond dairy milk almond cashew ->: dairy eggs dairy eggs other dairy beverages almond dairy milk almond cashew ->: other dairy beverages almond dairy milk almond cashew almond cashew
# 11 Minis Size Chocolate Candy Bars Variety Mix ->: snacks bars & nuts ->: other snacks: other snacks ->: snacks ->: snacks bars & nuts ->: other snacks: other snacks ->: snacks: other snacks ->: snacks bars & nuts ->: other snacks ->: snacks bars & nuts ->: other snacks: ->: other snacks: other snacks ->: snacks bars
# 12 Cheesy Cheddar Rotini Pasta Sides ->: dry goods pasta rice pasta sauces pasta side dishes international ->: missing eggs dairy egg products eggs eggs pasta ->: dry goods pasta rice pasta sauces pasta side dishes international pasta side dishes pasta sauce ->: dry goods pasta rice pasta sauces pasta side dishes international pasta sauce missing eggs dairy egg products eggs eggs pasta ->:
# 13 Multi Purpose Solution ->: personal care personal care babies & kids personal care baby care babies ->: baby care babies products babies products personal care products personal care products babies personal care products personal care baby care personal care baby care personal care personal care baby care personal ->: personal care personal care babies & kids personal care baby care babies personal care products for babies personal care baby care personal care products personal care products personal care
# 14 Juice, Raw & Cold-Pressed, Purity ->: beverages alcoholic beverages ->: beers, hard ciders & stouts: alcoholic beverages ->: beverages ->: beer ->: beer ->: non-alcoholic beer ->: juices and juice drink mixes ->: beverages ->: beverages ->: snacks snacks & bakery items ->: snacks ->:
# 15 Chinese Five Spices Powder ->: international aisles international products & gourmet foods ->: pantry staples ->: dry goods original products ->: international aisles international products & gourmet foods ->: pantry staples ->: dry goods ->: dry goods original products 952100742092 ->: international aisles international products & gourmet foods ->: pantry staples ->:
# 16 Ancient Grain Original Granola ->: breakfast cereals pasta, rice, beans & grains other pasta, rice, beans & grains pasta, rice, beans & grains pasta & cereal ->: breakfast cereals breakfast cereals ->: other pasta, rice, beans & grains breakfast cereals ->: pasta, rice, beans & grains other pasta, rice, beans & grains
# 17 Crunch Lemon Shortbread Flavor 0% Fat with Toppings Greek Yogurt ->: dairy eggs & dairy eggs eggs & dairy eggs cheese cheese ->: international cuisine international cuisine: international cuisine ->: international cuisine ->: dairy dairy: dairy dairy snacks ->: snacks snacks: snacks snacks ->: snacks dairy snacks dairy ->: dairy sn
# 18 Flounder Fillets ->: meat seafood fish ->: frozen seafood ->: seafood ->: fish ->: seafoon & seafood ->: seafood ->: frozen seafood ->: fish ->: frozen seafood ->: seafood ->: seafood ->: frozen seafood ->: seafood sea bass wild pacific sea bass ->: seafood ->: seafood ->: sea
# 19 Lilac Votive ->: household products personal care bathroom supplies ->: bath products personal care products deodorants ->: deodorants personal care products ->: personal care products deodorants ->: personal care products ->: personal care products deodorants antiperspirants/deodorants ->: personal care products deodorants ->: personal care products deodorants antiperspirants/deodorants laundry & household products household products personal care products
# 20 Cheese & Broccoli Ravioli For Kids ->: frozen foods seafood & veggie burgers & meals ravioli & lasagna frozen meals frozen meals ->: frozen meals international & organic frozen meals ->: frozen meals kids meals frozen meals pasta & sauces pasta & rice ->: pasta ravioli & lasagna pasta ravioli & lasagna pasta
# 21 Organic Soymilk Original Value Size ->: dairy eggs dairy eggs ->: international deli international deli: dairy eggs dairy eggs ->: international deli dairy eggs ->: tofu soy beans tofu soy beans: dairy eggs organic organic ->: dairy eggs international eggs international eggs international eggs dairy eggs eggs ->: international eggs international eggs dairy eggs dairy eggs international eggs eggs ->: international eggs international eggs dairy eggs eggs ->
# 22 Fruit Juice Sweetened Millet Rice Cereal ->: breakfast cereals oatmeal quaker ->: personal care household babies toddlers tots personal care babies toddlers tots ->: personal care babies toddlers tots personal care: pets & household household babies toddlers tots pets & household personal care personal care babies toddlers tots personal care: pets &
# 23 Morning Burst® Facial Scrub Cleansers ->: personal care personal care cosmetics facial care morning burst facial scrub cleansers ->: personal care personal care cosmetics facial care face cleansers morning burst facial scrub cleansers ->: personal care personal care cosmetics facial care face cleaning ->: personal care personal care cosmetics facial care face cleansers morning burst facial scrub cleansers ->
# 24 Salmon Pinwheels ->: meat seafood->: seafood lox & bagels ->: seafood ->: fish & seafood meat seafood beef ->: meat seafood ->: meat seafood chicken poultry ->: meat seafood ->: meat seafood seafood ->: meat seafood seafood ->: meat seafood seafood ->: meat seafood seafood ->

# %%
def correct_answer(ans):
  return (ans.split("->:")[1]).strip()

answers = []
for ix,seq in enumerate(sequences):
    # print(ix,seq[0]['generated_text'])
    answers.append(correct_answer(seq[0]['generated_text']))

answers
# Out:
# ['babies',
#  'frozen foods meat seafood & poultry',
#  'alcohol beverages liquor',
#  'bakery & dairy eggs & dairy eggs & dairy eggs & dairy eggs & dairy eggs',
#  'personal care personal wash personal hygiene',
#  'household essentials kitchen utensils baking & kitchen tools baking tools & gadgets dust pans & brooms',
#  'deli cheese eggs',
#  'beverages other drinks juices cranberry raspberry juice cocktail',
#  'dairy eggs dairy eggs eggs dairy eggs dairy eggs butter dairy eggs eggs dairy eggs dairy eggs',
#  'canned goods canned goods: soup',
#  'dairy eggs dairy eggs other dairy beverages almond dairy milk almond dairy milk almond cashew',
#  'snacks bars & nuts',
#  'dry goods pasta rice pasta sauces pasta side dishes international',
#  'personal care personal care babies & kids personal care baby care babies',
#  'beverages alcoholic beverages',
#  'international aisles international products & gourmet foods',
#  'breakfast cereals pasta, rice, beans & grains other pasta, rice, beans & grains pasta, rice, beans & grains pasta & cereal',
#  'dairy eggs & dairy eggs eggs & dairy eggs cheese cheese',
#  'meat seafood fish',
#  'household products personal care bathroom supplies',
#  'frozen foods seafood & veggie burgers & meals ravioli & lasagna frozen meals frozen meals',
#  'dairy eggs dairy eggs',
#  'breakfast cereals oatmeal quaker',
#  'personal care personal care cosmetics facial care morning burst facial scrub cleansers',
#  'meat seafood']

# %%
df_evaluate = test_df.iloc[:sample_size][['product_name','department']]

df_evaluate = df_evaluate.reset_index(drop=True)

df_evaluate['department_predicted'] = answers

df_evaluate
# Out:
#                                          product_name       department  \
# 0              Free & Clear Stage 4 Overnight Diapers           babies
# 1   Beef pot roast with roasted potatoes, carrots,...           frozen
# 2                                       Coffee Liquer          alcohol
# 3                                         Bread Rolls           bakery
# 4            French Milled Oval Almond Gourmande Soap    personal care
# 5                                            Dust Pan        household
# 6                             Roasted Pine Nut Hommus             deli
# 7                  Cranberry Raspberry Juice Cocktail        beverages
# 8                           Sweet Cream Butter Salted       dairy eggs
# 9                     Traditional Chicken Barley Soup     canned goods
# 10                     Vanilla Unsweetened Cashewmilk       dairy eggs
# 11        Minis Size Chocolate Candy Bars Variety Mix           snacks
# 12                  Cheesy Cheddar Rotini Pasta Sides  dry goods pasta
# 13                             Multi Purpose Solution    personal care
# 14                  Juice, Raw & Cold-Pressed, Purity        beverages
# 15                         Chinese Five Spices Powder    international
# 16                     Ancient Grain Original Granola        breakfast
# 17  Crunch Lemon Shortbread Flavor 0% Fat with Top...       dairy eggs
# 18                                   Flounder Fillets     meat seafood
# 19                                       Lilac Votive        household
# 20                 Cheese & Broccoli Ravioli For Kids           frozen
# 21                Organic Soymilk Original Value Size       dairy eggs
# 22           Fruit Juice Sweetened Millet Rice Cereal        breakfast
# 23              Morning Burst® Facial Scrub Cleansers    personal care
# 24                                   Salmon Pinwheels     meat seafood
#
#                                  department_predicted
# 0                                              babies
# 1                 frozen foods meat seafood & poultry
# 2                            alcohol beverages liquor
# 3   bakery & dairy eggs & dairy eggs & dairy eggs ...
# 4        personal care personal wash personal hygiene
# 5   household essentials kitchen utensils baking &...
# 6                                    deli cheese eggs
# 7   beverages other drinks juices cranberry raspbe...
# 8   dairy eggs dairy eggs eggs dairy eggs dairy eg...
# 9                     canned goods canned goods: soup
# 10  dairy eggs dairy eggs other dairy beverages al...
# 11                                 snacks bars & nuts
# 12  dry goods pasta rice pasta sauces pasta side d...
# 13  personal care personal care babies & kids pers...
# 14                      beverages alcoholic beverages
# 15  international aisles international products & ...
# 16  breakfast cereals pasta, rice, beans & grains ...
# 17  dairy eggs & dairy eggs eggs & dairy eggs chee...
# 18                                  meat seafood fish
# 19  household products personal care bathroom supp...
# 20  frozen foods seafood & veggie burgers & meals ...
# 21                              dairy eggs dairy eggs
# 22                   breakfast cereals oatmeal quaker
# 23  personal care personal care cosmetics facial c...
# 24                                       meat seafood
